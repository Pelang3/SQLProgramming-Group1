-- %% [markdown]
-- **Q5**
--
--
-- **The SELECT Clause**

-- %%
-- The SELECT Clause
---------------------------------------------------------------------


-- Original Query for TSQLV4
USE TSQLV4;

SELECT orderid, orderdate
FROM Sales.Orders;

-- New Query for Northwinds
USE Northwinds2022TSQLV7;

SELECT OrderId, OrderDate
FROM Sales.[Order];
-- Out:
-- (830 rows affected)
-- (830 rows affected)
-- Total execution time: 00:00:00.132
-- ...

-- %% [markdown]
-- <u><mark>**the proposition, table, columns and the predicate**</mark></u>
--
-- Proposition (Problem): Retrieve the orderid and orderdate from the Sales.Order table.(get all row from the order id and order data column from the table )
--
-- Table: Sales.Order
--
-- Columns: OrderId, OrderDate<span style="color: var(--vscode-foreground);"><br></span>
--
-- Predicate: There isn't a specific predicate explicitly stated in your query. However, the implicit predicate is to select all rows from the Sales.Order table.

-- %%
-- Original Query for TSQLV4
USE TSQLV4;

SELECT empid, YEAR(orderdate) AS orderyear, COUNT(*) AS numorders
FROM Sales.Orders
WHERE custid = 71
GROUP BY empid, YEAR(orderdate)
HAVING COUNT(*) > 1;


-- New Query for Northwinds
USE Northwinds2022TSQLV7;

SELECT EmployeeId, YEAR(OrderDate) AS orderyear, COUNT(*) AS numorders
FROM Sales.[Order]
WHERE CustomerId = 71
GROUP BY EmployeeId, YEAR(OrderDate)
HAVING COUNT(*) > 1;
-- Out:
-- (9 rows affected)
-- (9 rows affected)
-- Total execution time: 00:00:00.074
-- <table><tr><th>empid</th><th>orderyear</th><th>numorders</th></tr><tr><td>1</td><td>2015</td><td>2</td></tr><tr><td>3</td><td>2015</td><td>2</td></tr><tr><td>5</td><td>2015</td><td>3</td></tr><tr><td>6</td><td>2015</td><td>3</td></tr><tr><td>8</td><td>2015</td><td>4</td></tr><tr><td>1</td><td>2016</td><td>3</td></tr><tr><td>2</td><td>2016</td><td>2</td></tr><tr><td>4</td><td>2016</td><td>3</td></tr><tr><td>7</td><td>2016</td><td>2</td></tr></table>
-- <table><tr><th>EmployeeId</th><th>orderyear</th><th>numorders</th></tr><tr><td>1</td><td>2015</td><td>2</td></tr><tr><td>3</td><td>2015</td><td>2</td></tr><tr><td>5</td><td>2015</td><td>3</td></tr><tr><td>6</td><td>2015</td><td>3</td></tr><tr><td>8</td><td>2015</td><td>4</td></tr><tr><td>1</td><td>2016</td><td>3</td></tr><tr><td>2</td><td>2016</td><td>2</td></tr><tr><td>4</td><td>2016</td><td>3</td></tr><tr><td>7</td><td>2016</td><td>2</td></tr></table>

-- %% [markdown]
-- <u><mark>**the proposition, table, columns and the predicate**</mark></u>
--
-- <span style="margin-top: 0px; padding-top: 0px; color: rgb(74, 74, 74); background-color: rgb(255, 255, 254);">Proposition （</span>Problem）: Find the number of orders per employee for customer 71 in each year, but only display those employees who have more than one order in a year.
--
-- Table: Sales.Order
--
-- Columns: <span style="background-color: rgb(255, 255, 254); color: var(--vscode-foreground);">EmployeeId，</span><span style="background-color: rgb(255, 255, 254); color: var(--vscode-foreground);">OrderDate，</span><span style="background-color: rgb(255, 255, 254); color: var(--vscode-foreground);">CustomerId</span>
--
-- Predicate:
--
-- WHERE CustomerId = 71 - Selects only the orders made by customer 71.
--
-- GROUP BY EmployeeId, YEAR(OrderDate) - Groups the results by EmployeeId and the year extracted from OrderDate.
--
-- HAVING COUNT(\*) \> 1 - Specifies that only groups with more than one order will be selected.

-- %%
-- Original Query for TSQLV4
USE TSQLV4;

/*
SELECT orderid, YEAR(orderdate) AS orderyear
FROM Sales.Orders
WHERE orderyear > 2015;
*/

SELECT orderid, YEAR(orderdate) AS orderyear
FROM Sales.Orders
WHERE YEAR(orderdate) > 2015;


-- New Query for Northwinds
USE Northwinds2022TSQLV7;

SELECT OrderId, YEAR(OrderDate) AS orderyear
FROM Sales.[Order]
WHERE YEAR(orderdate) > 2015;
-- Out:
-- (270 rows affected)
-- (270 rows affected)
-- Total execution time: 00:00:00.115
-- ...

-- %% [markdown]
-- <u><mark>**the proposition, table, columns and the predicate**</mark></u>
--
-- Proposition (Problem): <span style="color: var(--vscode-foreground);">Retrieve the OrderId and the corresponding year from the Sales.[Order] table for orders placed after the year 2015.(show the order id and its year that is after the 2015)</span>
--
-- Table: <span style="color: var(--vscode-foreground);">Sales.[Order]</span>
--
-- Columns:  <span style="color: var(--vscode-foreground);">OrderId, YEAR(OrderDate) AS orderyear</span>
--
-- The OrderId column represents the unique identifier for each order.
--
-- The YEAR(OrderDate) AS orderyear expression calculates the year from the OrderDate and aliases it as orderyear.
--
-- Predicate:
--
-- WHERE Clause Predicate: YEAR(orderdate) \> 2015
--
-- This is the condition that filters the rows from the Sales.\[Order\] table. It selects only those rows where the year extracted from the OrderDate is greater than 2015.

-- %%
-- Original Query for TSQLV4
USE TSQLV4;

-- Listing 2-2: Query Returning Duplicate Rows
SELECT empid, YEAR(orderdate) AS orderyear
FROM Sales.Orders
WHERE custid = 71;

-- New Query for Northwinds
USE Northwinds2022TSQLV7;

-- Listing 2-2: Query Returning Duplicate Rows
SELECT EmployeeId, YEAR(OrderDate) AS orderyear
FROM Sales.[Order]
WHERE  CustomerId = 71;
-- Out:
-- (31 rows affected)
-- (31 rows affected)
-- Total execution time: 00:00:00.052
-- ...

-- %% [markdown]
-- <u><mark>**the proposition, table, columns and the predicate**</mark></u>
--
-- Proposition(Problem):<span style="color: var(--vscode-foreground);">Retrieve the EmployeeId and the year of OrderDate for orders made by CustomerId 71. (show the employee id and the order year that is purchased by customer id 71)</span>
--
-- Table:   <span style="color: var(--vscode-foreground);">&nbsp;Sales.[Order].</span>
--
-- Columns: <span style="color: var(--vscode-foreground);">EmployeeId,&nbsp;</span>   <span style="color: var(--vscode-foreground);">OrderDate</span>
--
-- Predicate:
--
-- CustomerId = 71: This condition filters the rows where the CustomerId is equal to 71.

-- %%
-- Original Query for TSQLV4
USE TSQLV4;

-- Listing 2-3: Query With a DISTINCT Clause
SELECT DISTINCT empid, YEAR(orderdate) AS orderyear
FROM Sales.Orders
WHERE custid = 71;


-- New Query for Northwinds
USE Northwinds2022TSQLV7;

-- Listing 2-3: Query With a DISTINCT Clause
SELECT DISTINCT EmployeeId, YEAR(OrderDate) AS orderyear
FROM Sales.[Order]
WHERE  CustomerId = 71;
-- Out:
-- (16 rows affected)
-- (16 rows affected)
-- Total execution time: 00:00:00.181
-- <table><tr><th>empid</th><th>orderyear</th></tr><tr><td>1</td><td>2014</td></tr><tr><td>1</td><td>2015</td></tr><tr><td>1</td><td>2016</td></tr><tr><td>2</td><td>2014</td></tr><tr><td>2</td><td>2015</td></tr><tr><td>2</td><td>2016</td></tr><tr><td>3</td><td>2015</td></tr><tr><td>4</td><td>2015</td></tr><tr><td>4</td><td>2016</td></tr><tr><td>5</td><td>2015</td></tr><tr><td>6</td><td>2015</td></tr><tr><td>6</td><td>2016</td></tr><tr><td>7</td><td>2015</td></tr><tr><td>7</td><td>2016</td></tr><tr><td>8</td><td>2015</td></tr><tr><td>9</td><td>2014</td></tr></table>
-- ...

-- %% [markdown]
-- <u><mark>**the proposition, table, columns and the predicate**</mark></u>
--
-- Proposition(<span style="color: var(--vscode-foreground);">Problem): Retrieve distinct EmployeeId and the year of OrderDate for orders made by CustomerId 71.(show the unique&nbsp; employeed id and&nbsp; unique the order year that is relative with customer id 71,)</span>
--
-- Table: Sales.\[Order\]
--
-- Columns: EmployeeId, OrderDate
--
-- Predicate: WHERE CustomerId = 71,the condition under which rows will be selected. In this case, it filters rows where the CustomerId is equal to 71.

-- %%
-- Original Query for TSQLV4
USE TSQLV4;

SELECT *
FROM Sales.Shippers;


-- New Query for Northwinds
USE Northwinds2022TSQLV7;

SELECT *
FROM Sales.Shipper;
-- Out:
-- (3 rows affected)
-- (3 rows affected)
-- Total execution time: 00:00:00.071
-- <table><tr><th>shipperid</th><th>companyname</th><th>phone</th></tr><tr><td>1</td><td>Shipper GVSUA</td><td>(503) 555-0137</td></tr><tr><td>2</td><td>Shipper ETYNR</td><td>(425) 555-0136</td></tr><tr><td>3</td><td>Shipper ZHISN</td><td>(415) 555-0138</td></tr></table>
-- <table><tr><th>ShipperId</th><th>ShipperCompanyName</th><th>PhoneNumber</th></tr><tr><td>1</td><td>Shipper GVSUA</td><td>(503) 555-0137</td></tr><tr><td>2</td><td>Shipper ETYNR</td><td>(425) 555-0136</td></tr><tr><td>3</td><td>Shipper ZHISN</td><td>(415) 555-0138</td></tr></table>

-- %% [markdown]
-- <u><mark>**the proposition, table, columns and the predicate**</mark></u><span style="color: var(--vscode-foreground);"><br></span>
--
-- <span style="color: var(--vscode-foreground);">Proposition(</span>Problem ): Retrieve all columns from the "Sales.Shipper" table.(show the all info about the sale shipper)
--
-- Table: Sales.Shipper
--
-- Columns: All columns (denoted by \*)
--
-- Predicate: There's no explicit predicate in the query, meaning it retrieves all rows from the Sales.Shipper table without applying any specific conditions or filters.

-- %%
-- Original Query for TSQLV4
USE TSQLV4;
/*
SELECT orderid,
  YEAR(orderdate) AS orderyear,
  orderyear + 1 AS nextyear
FROM Sales.Orders;
*/

SELECT orderid,
  YEAR(orderdate) AS orderyear,
  YEAR(orderdate) + 1 AS nextyear
FROM Sales.Orders;


-- New Query for Northwinds
USE Northwinds2022TSQLV7;


SELECT OrderId,
  YEAR(OrderDate) AS orderyear,
  YEAR(OrderDate) + 1 AS nextyear
FROM Sales.[Order];
-- Out:
-- (830 rows affected)
-- (830 rows affected)
-- Total execution time: 00:00:00.100
-- ...

-- %% [markdown]
-- <span style="color: var(--tw-prose-bold); border: 0px solid rgb(227, 227, 227); box-sizing: border-box; --tw-border-spacing-x: 0; --tw-border-spacing-y: 0; --tw-translate-x: 0; --tw-translate-y: 0; --tw-rotate: 0; --tw-skew-x: 0; --tw-skew-y: 0; --tw-scale-x: 1; --tw-scale-y: 1; --tw-pan-x: ; --tw-pan-y: ; --tw-pinch-zoom: ; --tw-scroll-snap-strictness: proximity; --tw-gradient-from-position: ; --tw-gradient-via-position: ; --tw-gradient-to-position: ; --tw-ordinal: ; --tw-slashed-zero: ; --tw-numeric-figure: ; --tw-numeric-spacing: ; --tw-numeric-fraction: ; --tw-ring-inset: ; --tw-ring-offset-width: 0px; --tw-ring-offset-color: #fff; --tw-ring-color: rgba(69,89,164,.5); --tw-ring-offset-shadow: 0 0 transparent; --tw-ring-shadow: 0 0 transparent; --tw-shadow: 0 0 transparent; --tw-shadow-colored: 0 0 transparent; --tw-blur: ; --tw-brightness: ; --tw-contrast: ; --tw-grayscale: ; --tw-hue-rotate: ; --tw-invert: ; --tw-saturate: ; --tw-sepia: ; --tw-drop-shadow: ; --tw-backdrop-blur: ; --tw-backdrop-brightness: ; --tw-backdrop-contrast: ; --tw-backdrop-grayscale: ; --tw-backdrop-hue-rotate: ; --tw-backdrop-invert: ; --tw-backdrop-opacity: ; --tw-backdrop-saturate: ; --tw-backdrop-sepia: ; font-weight: 600;"><u style="font-weight: 400;"><mark><strong>the proposition, table, columns and the predicate</strong></mark></u><br></span>
--
-- <span style="color: var(--tw-prose-bold); border: 0px solid rgb(227, 227, 227); box-sizing: border-box; --tw-border-spacing-x: 0; --tw-border-spacing-y: 0; --tw-translate-x: 0; --tw-translate-y: 0; --tw-rotate: 0; --tw-skew-x: 0; --tw-skew-y: 0; --tw-scale-x: 1; --tw-scale-y: 1; --tw-pan-x: ; --tw-pan-y: ; --tw-pinch-zoom: ; --tw-scroll-snap-strictness: proximity; --tw-gradient-from-position: ; --tw-gradient-via-position: ; --tw-gradient-to-position: ; --tw-ordinal: ; --tw-slashed-zero: ; --tw-numeric-figure: ; --tw-numeric-spacing: ; --tw-numeric-fraction: ; --tw-ring-inset: ; --tw-ring-offset-width: 0px; --tw-ring-offset-color: #fff; --tw-ring-color: rgba(69,89,164,.5); --tw-ring-offset-shadow: 0 0 transparent; --tw-ring-shadow: 0 0 transparent; --tw-shadow: 0 0 transparent; --tw-shadow-colored: 0 0 transparent; --tw-blur: ; --tw-brightness: ; --tw-contrast: ; --tw-grayscale: ; --tw-hue-rotate: ; --tw-invert: ; --tw-saturate: ; --tw-sepia: ; --tw-drop-shadow: ; --tw-backdrop-blur: ; --tw-backdrop-brightness: ; --tw-backdrop-contrast: ; --tw-backdrop-grayscale: ; --tw-backdrop-hue-rotate: ; --tw-backdrop-invert: ; --tw-backdrop-opacity: ; --tw-backdrop-saturate: ; --tw-backdrop-sepia: ; font-weight: 600;">Proposition(Problem)</span><span style="color: var(--vscode-foreground);">: Retrieve the OrderId along with the year of the order and the next year based on the OrderDate from the Sales.Order table.(show all row that is base on the sale order table,return the order id and it's year,and the next year)</span>
--
--
-- <span style="color: var(--tw-prose-bold); border: 0px solid rgb(227, 227, 227); box-sizing: border-box; --tw-border-spacing-x: 0; --tw-border-spacing-y: 0; --tw-translate-x: 0; --tw-translate-y: 0; --tw-rotate: 0; --tw-skew-x: 0; --tw-skew-y: 0; --tw-scale-x: 1; --tw-scale-y: 1; --tw-pan-x: ; --tw-pan-y: ; --tw-pinch-zoom: ; --tw-scroll-snap-strictness: proximity; --tw-gradient-from-position: ; --tw-gradient-via-position: ; --tw-gradient-to-position: ; --tw-ordinal: ; --tw-slashed-zero: ; --tw-numeric-figure: ; --tw-numeric-spacing: ; --tw-numeric-fraction: ; --tw-ring-inset: ; --tw-ring-offset-width: 0px; --tw-ring-offset-color: #fff; --tw-ring-color: rgba(69,89,164,.5); --tw-ring-offset-shadow: 0 0 transparent; --tw-ring-shadow: 0 0 transparent; --tw-shadow: 0 0 transparent; --tw-shadow-colored: 0 0 transparent; --tw-blur: ; --tw-brightness: ; --tw-contrast: ; --tw-grayscale: ; --tw-hue-rotate: ; --tw-invert: ; --tw-saturate: ; --tw-sepia: ; --tw-drop-shadow: ; --tw-backdrop-blur: ; --tw-backdrop-brightness: ; --tw-backdrop-contrast: ; --tw-backdrop-grayscale: ; --tw-backdrop-hue-rotate: ; --tw-backdrop-invert: ; --tw-backdrop-opacity: ; --tw-backdrop-saturate: ; --tw-backdrop-sepia: ; font-weight: 600;">Table</span><span style="color: var(--vscode-foreground);">: Sales.Order</span>
--
-- <span style="color: var(--tw-prose-bold); border: 0px solid rgb(227, 227, 227); box-sizing: border-box; --tw-border-spacing-x: 0; --tw-border-spacing-y: 0; --tw-translate-x: 0; --tw-translate-y: 0; --tw-rotate: 0; --tw-skew-x: 0; --tw-skew-y: 0; --tw-scale-x: 1; --tw-scale-y: 1; --tw-pan-x: ; --tw-pan-y: ; --tw-pinch-zoom: ; --tw-scroll-snap-strictness: proximity; --tw-gradient-from-position: ; --tw-gradient-via-position: ; --tw-gradient-to-position: ; --tw-ordinal: ; --tw-slashed-zero: ; --tw-numeric-figure: ; --tw-numeric-spacing: ; --tw-numeric-fraction: ; --tw-ring-inset: ; --tw-ring-offset-width: 0px; --tw-ring-offset-color: #fff; --tw-ring-color: rgba(69,89,164,.5); --tw-ring-offset-shadow: 0 0 transparent; --tw-ring-shadow: 0 0 transparent; --tw-shadow: 0 0 transparent; --tw-shadow-colored: 0 0 transparent; --tw-blur: ; --tw-brightness: ; --tw-contrast: ; --tw-grayscale: ; --tw-hue-rotate: ; --tw-invert: ; --tw-saturate: ; --tw-sepia: ; --tw-drop-shadow: ; --tw-backdrop-blur: ; --tw-backdrop-brightness: ; --tw-backdrop-contrast: ; --tw-backdrop-grayscale: ; --tw-backdrop-hue-rotate: ; --tw-backdrop-invert: ; --tw-backdrop-opacity: ; --tw-backdrop-saturate: ; --tw-backdrop-sepia: ; font-weight: 600;">Columns</span><span style="color: var(--vscode-foreground);">: OrderId, YEAR(OrderDate) AS orderyear, YEAR(OrderDate) + 1 AS nextyear</span>
--
-- <span style="color: var(--tw-prose-bold); border: 0px solid rgb(227, 227, 227); box-sizing: border-box; --tw-border-spacing-x: 0; --tw-border-spacing-y: 0; --tw-translate-x: 0; --tw-translate-y: 0; --tw-rotate: 0; --tw-skew-x: 0; --tw-skew-y: 0; --tw-scale-x: 1; --tw-scale-y: 1; --tw-pan-x: ; --tw-pan-y: ; --tw-pinch-zoom: ; --tw-scroll-snap-strictness: proximity; --tw-gradient-from-position: ; --tw-gradient-via-position: ; --tw-gradient-to-position: ; --tw-ordinal: ; --tw-slashed-zero: ; --tw-numeric-figure: ; --tw-numeric-spacing: ; --tw-numeric-fraction: ; --tw-ring-inset: ; --tw-ring-offset-width: 0px; --tw-ring-offset-color: #fff; --tw-ring-color: rgba(69,89,164,.5); --tw-ring-offset-shadow: 0 0 transparent; --tw-ring-shadow: 0 0 transparent; --tw-shadow: 0 0 transparent; --tw-shadow-colored: 0 0 transparent; --tw-blur: ; --tw-brightness: ; --tw-contrast: ; --tw-grayscale: ; --tw-hue-rotate: ; --tw-invert: ; --tw-saturate: ; --tw-sepia: ; --tw-drop-shadow: ; --tw-backdrop-blur: ; --tw-backdrop-brightness: ; --tw-backdrop-contrast: ; --tw-backdrop-grayscale: ; --tw-backdrop-hue-rotate: ; --tw-backdrop-invert: ; --tw-backdrop-opacity: ; --tw-backdrop-saturate: ; --tw-backdrop-sepia: ; font-weight: 600;">Predicate</span><span style="color: var(--vscode-foreground);">: There isn't a specific predicate in the query. However, the query utilizes the function YEAR() to extract the year from the OrderDate column. It also performs a simple arithmetic operation to get the next year by adding 1 to the year obtained from OrderDate.</span>

-- %% [markdown]
-- ### **Q6**
--
-- ### **The ORDER BY Clause**

-- %%
-- The ORDER BY Clause


-- Original Query for TSQLV4
USE TSQLV4;

-- Listing 2-4: Query Demonstrating the ORDER BY Clause
SELECT empid, YEAR(orderdate) AS orderyear, COUNT(*) AS numorders
FROM Sales.Orders
WHERE custid = 71
GROUP BY empid, YEAR(orderdate)
HAVING COUNT(*) > 1
ORDER BY empid, orderyear;



-- New Query for Northwinds
USE Northwinds2022TSQLV7;

SELECT EmployeeId, YEAR(OrderDate) AS orderyear, COUNT(*) AS numorders
FROM Sales.[Order]
WHERE CustomerId = 71
GROUP BY EmployeeId, YEAR(OrderDate)
HAVING COUNT(*) > 1
ORDER BY EmployeeId, orderyear;
-- Out:
-- (9 rows affected)
-- (9 rows affected)
-- Total execution time: 00:00:00.218
-- <table><tr><th>empid</th><th>orderyear</th><th>numorders</th></tr><tr><td>1</td><td>2015</td><td>2</td></tr><tr><td>1</td><td>2016</td><td>3</td></tr><tr><td>2</td><td>2016</td><td>2</td></tr><tr><td>3</td><td>2015</td><td>2</td></tr><tr><td>4</td><td>2016</td><td>3</td></tr><tr><td>5</td><td>2015</td><td>3</td></tr><tr><td>6</td><td>2015</td><td>3</td></tr><tr><td>7</td><td>2016</td><td>2</td></tr><tr><td>8</td><td>2015</td><td>4</td></tr></table>
-- <table><tr><th>EmployeeId</th><th>orderyear</th><th>numorders</th></tr><tr><td>1</td><td>2015</td><td>2</td></tr><tr><td>1</td><td>2016</td><td>3</td></tr><tr><td>2</td><td>2016</td><td>2</td></tr><tr><td>3</td><td>2015</td><td>2</td></tr><tr><td>4</td><td>2016</td><td>3</td></tr><tr><td>5</td><td>2015</td><td>3</td></tr><tr><td>6</td><td>2015</td><td>3</td></tr><tr><td>7</td><td>2016</td><td>2</td></tr><tr><td>8</td><td>2015</td><td>4</td></tr></table>

-- %% [markdown]
-- <u><mark>**the proposition, table, columns and the predicate**</mark></u><span style="white-space-collapse: preserve; color: var(--vscode-foreground); font-size: 16px;"><br></span>
--
-- <span style="white-space-collapse: preserve; color: var(--vscode-foreground); font-size: 16px;">Proposition (Problem):Retrieve the number of orders made by each employee in each year, for orders placed by customer with ID 71, where the count of orders is greater than 1, and order the results by employee ID and order year.</span>
--
-- <span style="white-space-collapse: preserve; color: var(--vscode-foreground); font-size: 16px;">Table: Sales.[Order].</span>
--
-- <span style="white-space-collapse: preserve; color: var(--vscode-foreground); font-size: 16px;">Columns: EmployeeId, YEAR(OrderDate) AS orderyear, COUNT(*) AS numorders: </span> <span style="white-space-collapse: preserve; color: rgb(13, 13, 13); font-family: Söhne, ui-sans-serif, system-ui, -apple-system, &quot;Segoe UI&quot;, Roboto, Ubuntu, Cantarell, &quot;Noto Sans&quot;, sans-serif, &quot;Helvetica Neue&quot;, Arial, &quot;Apple Color Emoji&quot;, &quot;Segoe UI Emoji&quot;, &quot;Segoe UI Symbol&quot;, &quot;Noto Color Emoji&quot;; font-size: 16px;">Counts the number of orders made by each employee in each year</span><span style="font-size: 16px; white-space-collapse: preserve; color: var(--vscode-foreground);"><br></span>
--
-- <span style="font-size: 16px; white-space-collapse: preserve; color: var(--vscode-foreground);">Predicate:</span>
-- <span style="font-size: 16px; white-space-collapse: preserve; color: var(--vscode-foreground);">CustomerId = 71: Filters the orders where the CustomerId is equal to 71. HAVING COUNT(*) &gt; 1: Ensures that only records with more than one order are included in the results.</span>
-- <span style="font-size: 16px; white-space-collapse: preserve; color: var(--vscode-foreground);">ORDER BY: The final result is ordered by EmployeeId and then by orderyear.</span>
--
-- <span style="font-size: 16px; white-space-collapse: preserve;">GROUP BY clause groups the rows based on the columns specified within it. In this case, the query groups the rows by EmployeeId and the year extracted from the OrderDate (using YEAR(OrderDate)).</span>

-- %%
-- Original Query for TSQLV4
USE TSQLV4;

SELECT empid, firstname, lastname, country
FROM HR.Employees
ORDER BY hiredate;



-- New Query for Northwinds
USE Northwinds2022TSQLV7;

SELECT EmployeeId, EmployeeFirstName, EmployeeLastName, EmployeeCountry
FROM HumanResources.[Employee]
ORDER BY HireDate;
-- Out:
-- (9 rows affected)
-- (9 rows affected)
-- Total execution time: 00:00:00.188
-- <table><tr><th>empid</th><th>firstname</th><th>lastname</th><th>country</th></tr><tr><td>3</td><td>Judy</td><td>Lew</td><td>USA</td></tr><tr><td>1</td><td>Sara</td><td>Davis</td><td>USA</td></tr><tr><td>2</td><td>Don</td><td>Funk</td><td>USA</td></tr><tr><td>4</td><td>Yael</td><td>Peled</td><td>USA</td></tr><tr><td>5</td><td>Sven</td><td>Mortensen</td><td>UK</td></tr><tr><td>6</td><td>Paul</td><td>Suurs</td><td>UK</td></tr><tr><td>7</td><td>Russell</td><td>King</td><td>UK</td></tr><tr><td>8</td><td>Maria</td><td>Cameron</td><td>USA</td></tr><tr><td>9</td><td>Patricia</td><td>Doyle</td><td>UK</td></tr></table>
-- ...

-- %% [markdown]
-- <span style="border: 0px solid rgb(227, 227, 227); box-sizing: border-box; --tw-border-spacing-x: 0; --tw-border-spacing-y: 0; --tw-translate-x: 0; --tw-translate-y: 0; --tw-rotate: 0; --tw-skew-x: 0; --tw-skew-y: 0; --tw-scale-x: 1; --tw-scale-y: 1; --tw-pan-x: ; --tw-pan-y: ; --tw-pinch-zoom: ; --tw-scroll-snap-strictness: proximity; --tw-gradient-from-position: ; --tw-gradient-via-position: ; --tw-gradient-to-position: ; --tw-ordinal: ; --tw-slashed-zero: ; --tw-numeric-figure: ; --tw-numeric-spacing: ; --tw-numeric-fraction: ; --tw-ring-inset: ; --tw-ring-offset-width: 0px; --tw-ring-offset-color: #fff; --tw-ring-color: rgba(69,89,164,.5); --tw-ring-offset-shadow: 0 0 transparent; --tw-ring-shadow: 0 0 transparent; --tw-shadow: 0 0 transparent; --tw-shadow-colored: 0 0 transparent; --tw-blur: ; --tw-brightness: ; --tw-contrast: ; --tw-grayscale: ; --tw-hue-rotate: ; --tw-invert: ; --tw-saturate: ; --tw-sepia: ; --tw-drop-shadow: ; --tw-backdrop-blur: ; --tw-backdrop-brightness: ; --tw-backdrop-contrast: ; --tw-backdrop-grayscale: ; --tw-backdrop-hue-rotate: ; --tw-backdrop-invert: ; --tw-backdrop-opacity: ; --tw-backdrop-saturate: ; --tw-backdrop-sepia: ; color: var(--tw-prose-bold);"><u><mark><strong>the proposition, table, columns and the predicate</strong></mark></u><br></span>
--
-- <span style="border: 0px solid rgb(227, 227, 227); box-sizing: border-box; --tw-border-spacing-x: 0; --tw-border-spacing-y: 0; --tw-translate-x: 0; --tw-translate-y: 0; --tw-rotate: 0; --tw-skew-x: 0; --tw-skew-y: 0; --tw-scale-x: 1; --tw-scale-y: 1; --tw-pan-x: ; --tw-pan-y: ; --tw-pinch-zoom: ; --tw-scroll-snap-strictness: proximity; --tw-gradient-from-position: ; --tw-gradient-via-position: ; --tw-gradient-to-position: ; --tw-ordinal: ; --tw-slashed-zero: ; --tw-numeric-figure: ; --tw-numeric-spacing: ; --tw-numeric-fraction: ; --tw-ring-inset: ; --tw-ring-offset-width: 0px; --tw-ring-offset-color: #fff; --tw-ring-color: rgba(69,89,164,.5); --tw-ring-offset-shadow: 0 0 transparent; --tw-ring-shadow: 0 0 transparent; --tw-shadow: 0 0 transparent; --tw-shadow-colored: 0 0 transparent; --tw-blur: ; --tw-brightness: ; --tw-contrast: ; --tw-grayscale: ; --tw-hue-rotate: ; --tw-invert: ; --tw-saturate: ; --tw-sepia: ; --tw-drop-shadow: ; --tw-backdrop-blur: ; --tw-backdrop-brightness: ; --tw-backdrop-contrast: ; --tw-backdrop-grayscale: ; --tw-backdrop-hue-rotate: ; --tw-backdrop-invert: ; --tw-backdrop-opacity: ; --tw-backdrop-saturate: ; --tw-backdrop-sepia: ; color: var(--tw-prose-bold);">Proposition（Problem）</span>: Retrieve specific columns from the "Employee" table and order the results by the "HireDate" column.(showing all the HR infor that  relative country,first name,last name, employee id and order by the hire date)
--
-- <span style="border: 0px solid rgb(227, 227, 227); box-sizing: border-box; --tw-border-spacing-x: 0; --tw-border-spacing-y: 0; --tw-translate-x: 0; --tw-translate-y: 0; --tw-rotate: 0; --tw-skew-x: 0; --tw-skew-y: 0; --tw-scale-x: 1; --tw-scale-y: 1; --tw-pan-x: ; --tw-pan-y: ; --tw-pinch-zoom: ; --tw-scroll-snap-strictness: proximity; --tw-gradient-from-position: ; --tw-gradient-via-position: ; --tw-gradient-to-position: ; --tw-ordinal: ; --tw-slashed-zero: ; --tw-numeric-figure: ; --tw-numeric-spacing: ; --tw-numeric-fraction: ; --tw-ring-inset: ; --tw-ring-offset-width: 0px; --tw-ring-offset-color: #fff; --tw-ring-color: rgba(69,89,164,.5); --tw-ring-offset-shadow: 0 0 transparent; --tw-ring-shadow: 0 0 transparent; --tw-shadow: 0 0 transparent; --tw-shadow-colored: 0 0 transparent; --tw-blur: ; --tw-brightness: ; --tw-contrast: ; --tw-grayscale: ; --tw-hue-rotate: ; --tw-invert: ; --tw-saturate: ; --tw-sepia: ; --tw-drop-shadow: ; --tw-backdrop-blur: ; --tw-backdrop-brightness: ; --tw-backdrop-contrast: ; --tw-backdrop-grayscale: ; --tw-backdrop-hue-rotate: ; --tw-backdrop-invert: ; --tw-backdrop-opacity: ; --tw-backdrop-saturate: ; --tw-backdrop-sepia: ; color: var(--tw-prose-bold);">Table</span>: HumanResources.Employee
--
-- <span style="border: 0px solid rgb(227, 227, 227); box-sizing: border-box; --tw-border-spacing-x: 0; --tw-border-spacing-y: 0; --tw-translate-x: 0; --tw-translate-y: 0; --tw-rotate: 0; --tw-skew-x: 0; --tw-skew-y: 0; --tw-scale-x: 1; --tw-scale-y: 1; --tw-pan-x: ; --tw-pan-y: ; --tw-pinch-zoom: ; --tw-scroll-snap-strictness: proximity; --tw-gradient-from-position: ; --tw-gradient-via-position: ; --tw-gradient-to-position: ; --tw-ordinal: ; --tw-slashed-zero: ; --tw-numeric-figure: ; --tw-numeric-spacing: ; --tw-numeric-fraction: ; --tw-ring-inset: ; --tw-ring-offset-width: 0px; --tw-ring-offset-color: #fff; --tw-ring-color: rgba(69,89,164,.5); --tw-ring-offset-shadow: 0 0 transparent; --tw-ring-shadow: 0 0 transparent; --tw-shadow: 0 0 transparent; --tw-shadow-colored: 0 0 transparent; --tw-blur: ; --tw-brightness: ; --tw-contrast: ; --tw-grayscale: ; --tw-hue-rotate: ; --tw-invert: ; --tw-saturate: ; --tw-sepia: ; --tw-drop-shadow: ; --tw-backdrop-blur: ; --tw-backdrop-brightness: ; --tw-backdrop-contrast: ; --tw-backdrop-grayscale: ; --tw-backdrop-hue-rotate: ; --tw-backdrop-invert: ; --tw-backdrop-opacity: ; --tw-backdrop-saturate: ; --tw-backdrop-sepia: ; color: var(--tw-prose-bold);">Columns</span>:
--
-- <span style="color: var(--vscode-foreground);">EmployeeId</span>
-- <span style="color: var(--vscode-foreground);">EmployeeFirstName</span>
-- <span style="color: var(--vscode-foreground);">EmployeeLastName</span>
-- <span style="color: var(--vscode-foreground);">EmployeeCountry</span>
--
-- <span style="border: 0px solid rgb(227, 227, 227); box-sizing: border-box; --tw-border-spacing-x: 0; --tw-border-spacing-y: 0; --tw-translate-x: 0; --tw-translate-y: 0; --tw-rotate: 0; --tw-skew-x: 0; --tw-skew-y: 0; --tw-scale-x: 1; --tw-scale-y: 1; --tw-pan-x: ; --tw-pan-y: ; --tw-pinch-zoom: ; --tw-scroll-snap-strictness: proximity; --tw-gradient-from-position: ; --tw-gradient-via-position: ; --tw-gradient-to-position: ; --tw-ordinal: ; --tw-slashed-zero: ; --tw-numeric-figure: ; --tw-numeric-spacing: ; --tw-numeric-fraction: ; --tw-ring-inset: ; --tw-ring-offset-width: 0px; --tw-ring-offset-color: #fff; --tw-ring-color: rgba(69,89,164,.5); --tw-ring-offset-shadow: 0 0 transparent; --tw-ring-shadow: 0 0 transparent; --tw-shadow: 0 0 transparent; --tw-shadow-colored: 0 0 transparent; --tw-blur: ; --tw-brightness: ; --tw-contrast: ; --tw-grayscale: ; --tw-hue-rotate: ; --tw-invert: ; --tw-saturate: ; --tw-sepia: ; --tw-drop-shadow: ; --tw-backdrop-blur: ; --tw-backdrop-brightness: ; --tw-backdrop-contrast: ; --tw-backdrop-grayscale: ; --tw-backdrop-hue-rotate: ; --tw-backdrop-invert: ; --tw-backdrop-opacity: ; --tw-backdrop-saturate: ; --tw-backdrop-sepia: ; color: var(--tw-prose-bold);">Predicate</span>: There is no specific predicate defined in the query. The query simply selects all rows from the "Employee" table

-- %% [markdown]
-- ### **Q7**
--
-- ### **1.The TOP Filter**

-- %%
-- The TOP Filter

-- Original Query for TSQLV4
USE TSQLV4;

-- Listing 2-5: Query Demonstrating the TOP Option
SELECT TOP (5) orderid, orderdate, custid, empid
FROM Sales.Orders
ORDER BY orderdate DESC;



-- New Query for Northwinds
USE Northwinds2022TSQLV7;

-- Listing 2-5: Query Demonstrating the TOP Option
SELECT TOP (5) OrderId, OrderDate, CustomerId, EmployeeId
FROM Sales.[Order]
ORDER BY OrderDate DESC;
-- Out:
-- (5 rows affected)
-- (5 rows affected)
-- Total execution time: 00:00:00.232
-- <table><tr><th>orderid</th><th>orderdate</th><th>custid</th><th>empid</th></tr><tr><td>11077</td><td>2016-05-06</td><td>65</td><td>1</td></tr><tr><td>11076</td><td>2016-05-06</td><td>9</td><td>4</td></tr><tr><td>11075</td><td>2016-05-06</td><td>68</td><td>8</td></tr><tr><td>11074</td><td>2016-05-06</td><td>73</td><td>7</td></tr><tr><td>11073</td><td>2016-05-05</td><td>58</td><td>2</td></tr></table>
-- <table><tr><th>OrderId</th><th>OrderDate</th><th>CustomerId</th><th>EmployeeId</th></tr><tr><td>11074</td><td>2016-05-06</td><td>73</td><td>7</td></tr><tr><td>11075</td><td>2016-05-06</td><td>68</td><td>8</td></tr><tr><td>11076</td><td>2016-05-06</td><td>9</td><td>4</td></tr><tr><td>11077</td><td>2016-05-06</td><td>65</td><td>1</td></tr><tr><td>11070</td><td>2016-05-05</td><td>44</td><td>2</td></tr></table>

-- %% [markdown]
-- <u><mark>**the proposition, table, columns and the predicate**</mark></u>
--
-- Proposition(Problem): Retrieve the top 5 records from the Sales.Order table, sorted by OrderDate in descending order.
--
-- Table: Sales.Order
--
-- Columns: OrderId, OrderDate, CustomerId, EmployeeId
--
-- Predicate: None specified explicitly; however, the query orders the results by the OrderDate column in descending order.

-- %%
-- Original Query for TSQLV4
USE TSQLV4;

SELECT TOP (1) PERCENT orderid, orderdate, custid, empid
FROM Sales.Orders
ORDER BY orderdate DESC;



-- New Query for Northwinds
USE Northwinds2022TSQLV7;

-- Listing 2-5: Query Demonstrating the TOP Option
SELECT TOP (1) PERCENT OrderId, OrderDate, CustomerId, EmployeeId
FROM Sales.[Order]
ORDER BY OrderDate DESC;
-- Out:
-- (9 rows affected)
-- (9 rows affected)
-- Total execution time: 00:00:00.181
-- <table><tr><th>orderid</th><th>orderdate</th><th>custid</th><th>empid</th></tr><tr><td>11074</td><td>2016-05-06</td><td>73</td><td>7</td></tr><tr><td>11075</td><td>2016-05-06</td><td>68</td><td>8</td></tr><tr><td>11076</td><td>2016-05-06</td><td>9</td><td>4</td></tr><tr><td>11077</td><td>2016-05-06</td><td>65</td><td>1</td></tr><tr><td>11070</td><td>2016-05-05</td><td>44</td><td>2</td></tr><tr><td>11071</td><td>2016-05-05</td><td>46</td><td>1</td></tr><tr><td>11072</td><td>2016-05-05</td><td>20</td><td>4</td></tr><tr><td>11073</td><td>2016-05-05</td><td>58</td><td>2</td></tr><tr><td>11067</td><td>2016-05-04</td><td>17</td><td>1</td></tr></table>
-- ...

-- %% [markdown]
-- <u><mark>**the proposition, table, columns and the predicate**</mark></u>
--
-- Proposition (Problem): Retrieve a specified percentage of records from the Sales.Order table, ordered by the OrderDate column in descending order.
--
-- Table: Sales.Order
--
-- Columns:
--
-- OrderId
--
-- OrderDate
--
-- CustomerId
--
-- EmployeeId
--
-- Predicate:
--
-- SELECT TOP (1) PERCENT: This specifies that we want to retrieve a certain percentage of records from the result set. In this case, it's the top 1 percent.
--
-- FROM Sales.Order: Indicates the table from which we want to retrieve the records.
--
-- ORDER BY OrderDate DESC: Orders the result set by the OrderDate column in descending order.

-- %%
-- Original Query for TSQLV4
USE TSQLV4;

-- Listing 2-6: Query Demonstrating TOP with Unique ORDER BY List
SELECT TOP (5) orderid, orderdate, custid, empid
FROM Sales.Orders
ORDER BY orderdate DESC, orderid DESC


-- New Query for Northwinds
USE Northwinds2022TSQLV7;

SELECT TOP (5)  OrderId, OrderDate, CustomerId, EmployeeId
FROM Sales.[Order]
ORDER BY OrderDate DESC, Orderid DESC;
-- Out:
-- (5 rows affected)
-- (5 rows affected)
-- Total execution time: 00:00:00.082
-- <table><tr><th>orderid</th><th>orderdate</th><th>custid</th><th>empid</th></tr><tr><td>11077</td><td>2016-05-06</td><td>65</td><td>1</td></tr><tr><td>11076</td><td>2016-05-06</td><td>9</td><td>4</td></tr><tr><td>11075</td><td>2016-05-06</td><td>68</td><td>8</td></tr><tr><td>11074</td><td>2016-05-06</td><td>73</td><td>7</td></tr><tr><td>11073</td><td>2016-05-05</td><td>58</td><td>2</td></tr></table>
-- <table><tr><th>OrderId</th><th>OrderDate</th><th>CustomerId</th><th>EmployeeId</th></tr><tr><td>11077</td><td>2016-05-06</td><td>65</td><td>1</td></tr><tr><td>11076</td><td>2016-05-06</td><td>9</td><td>4</td></tr><tr><td>11075</td><td>2016-05-06</td><td>68</td><td>8</td></tr><tr><td>11074</td><td>2016-05-06</td><td>73</td><td>7</td></tr><tr><td>11073</td><td>2016-05-05</td><td>58</td><td>2</td></tr></table>

-- %% [markdown]
-- <u><mark>**the proposition, table, columns and the predicate**</mark></u>
--
-- Proposition (problem):<span style="color: var(--vscode-foreground);">Retrieve the top 5 records from the Sales.Order table.(showing the&nbsp;</span>  OrderId, OrderDate, CustomerId, EmployeeId from the sales order,and the date,order id need be desc order<span style="color: var(--vscode-foreground);">)</span>
--
-- Table: <span style="color: var(--vscode-foreground);">Sales.Order</span>
--
-- Columns:
--
-- OrderId
--
-- OrderDate
--
-- CustomerId
--
-- EmployeeId
--
-- Predicate:
--
-- There is no predicate for filtering the rows. The query retrieves the top 5 records from the Sales.Order table without any additional conditions.
--
-- ORDER BY Clause:
--
-- OrderDate DESC, OrderId DESC
--
-- Sorting the result set in descending order based on OrderDate and, if there are ties, further sorting by OrderId in descending order.

-- %%
-- Original Query for TSQLV4
USE TSQLV4

SELECT TOP (5) WITH TIES orderid, orderdate, custid, empid
FROM Sales.Orders
ORDER BY orderdate DESC;



-- New Query for Northwinds
USE Northwinds2022TSQLV7;

SELECT TOP (5) WITH TIES OrderId, OrderDate, CustomerId, EmployeeId
FROM Sales.[Order]
ORDER BY OrderDate DESC ;
-- Out:
-- (8 rows affected)
-- (8 rows affected)
-- Total execution time: 00:00:00.132
-- <table><tr><th>orderid</th><th>orderdate</th><th>custid</th><th>empid</th></tr><tr><td>11074</td><td>2016-05-06</td><td>73</td><td>7</td></tr><tr><td>11075</td><td>2016-05-06</td><td>68</td><td>8</td></tr><tr><td>11076</td><td>2016-05-06</td><td>9</td><td>4</td></tr><tr><td>11077</td><td>2016-05-06</td><td>65</td><td>1</td></tr><tr><td>11070</td><td>2016-05-05</td><td>44</td><td>2</td></tr><tr><td>11071</td><td>2016-05-05</td><td>46</td><td>1</td></tr><tr><td>11072</td><td>2016-05-05</td><td>20</td><td>4</td></tr><tr><td>11073</td><td>2016-05-05</td><td>58</td><td>2</td></tr></table>
-- ...

-- %% [markdown]
-- <u><mark>**the proposition, table, columns and the predicate**</mark></u>
--
-- Proposition (Problem): <span style="color: var(--vscode-foreground);">Retrieve the top 5 orders with the latest order dates, including the OrderId, OrderDate, CustomerId, and EmployeeId from the Sales.Orders table.</span>
--
-- Table: <span style="color: var(--vscode-foreground);">Sales.Orders</span>
--
-- Columns:
--
-- OrderId
--
-- OrderDate
--
-- CustomerId
--
-- EmployeeId
--
-- Predicate:
--
-- the ordering of the results based on the OrderDate column in descending order.ORDER BY OrderDate DESC
--
-- The TOP (5) WITH TIES clause instructs SQL Server to return the top 5 rows from the result set, and if there are ties (i.e., multiple rows with the same value in the ORDER BY column), all tied rows are included.
--
-- In this case, it appears that there are ties in the OrderDate column, and SQL Server is including all tied rows.

-- %% [markdown]
-- ### **Q7**
--
-- ### <span style="color: var(--vscode-foreground);"><b>2.The OFFSET-FETCH Filter</b></span>

-- %%
-- The OFFSET-FETCH Filter

-- Original Query for TSQLV4
USE TSQLV4

SELECT orderid, orderdate, custid, empid
FROM Sales.Orders
ORDER BY orderdate, orderid
OFFSET 50 ROWS FETCH NEXT 25 ROWS ONLY;

-- New Query for Northwinds
USE Northwinds2022TSQLV7;

SELECT OrderId, OrderDate, CustomerId, EmployeeId
FROM Sales.[Order]
ORDER BY OrderDate, OrderId
OFFSET 50 ROWS FETCH NEXT 25 ROWS ONLY;
-- Out:
-- (25 rows affected)
-- (25 rows affected)
-- Total execution time: 00:00:00.223
-- ...

-- %% [markdown]
-- <u><mark>**the proposition, table, columns and the predicate**</mark></u>
--
-- <span style="color: var(--tw-prose-bold); border: 0px solid rgb(227, 227, 227); box-sizing: border-box; --tw-border-spacing-x: 0; --tw-border-spacing-y: 0; --tw-translate-x: 0; --tw-translate-y: 0; --tw-rotate: 0; --tw-skew-x: 0; --tw-skew-y: 0; --tw-scale-x: 1; --tw-scale-y: 1; --tw-pan-x: ; --tw-pan-y: ; --tw-pinch-zoom: ; --tw-scroll-snap-strictness: proximity; --tw-gradient-from-position: ; --tw-gradient-via-position: ; --tw-gradient-to-position: ; --tw-ordinal: ; --tw-slashed-zero: ; --tw-numeric-figure: ; --tw-numeric-spacing: ; --tw-numeric-fraction: ; --tw-ring-inset: ; --tw-ring-offset-width: 0px; --tw-ring-offset-color: #fff; --tw-ring-color: rgba(69,89,164,.5); --tw-ring-offset-shadow: 0 0 transparent; --tw-ring-shadow: 0 0 transparent; --tw-shadow: 0 0 transparent; --tw-shadow-colored: 0 0 transparent; --tw-blur: ; --tw-brightness: ; --tw-contrast: ; --tw-grayscale: ; --tw-hue-rotate: ; --tw-invert: ; --tw-saturate: ; --tw-sepia: ; --tw-drop-shadow: ; --tw-backdrop-blur: ; --tw-backdrop-brightness: ; --tw-backdrop-contrast: ; --tw-backdrop-grayscale: ; --tw-backdrop-hue-rotate: ; --tw-backdrop-invert: ; --tw-backdrop-opacity: ; --tw-backdrop-saturate: ; --tw-backdrop-sepia: ;">Proposition (Problem)</span><span style="color: var(--vscode-foreground);">: Retrieve specific columns from the "Sales.Order" table with pagination, ordering the results by "OrderDate" and "OrderId".</span>
--
--
-- <span style="color: var(--tw-prose-bold); border: 0px solid rgb(227, 227, 227); box-sizing: border-box; --tw-border-spacing-x: 0; --tw-border-spacing-y: 0; --tw-translate-x: 0; --tw-translate-y: 0; --tw-rotate: 0; --tw-skew-x: 0; --tw-skew-y: 0; --tw-scale-x: 1; --tw-scale-y: 1; --tw-pan-x: ; --tw-pan-y: ; --tw-pinch-zoom: ; --tw-scroll-snap-strictness: proximity; --tw-gradient-from-position: ; --tw-gradient-via-position: ; --tw-gradient-to-position: ; --tw-ordinal: ; --tw-slashed-zero: ; --tw-numeric-figure: ; --tw-numeric-spacing: ; --tw-numeric-fraction: ; --tw-ring-inset: ; --tw-ring-offset-width: 0px; --tw-ring-offset-color: #fff; --tw-ring-color: rgba(69,89,164,.5); --tw-ring-offset-shadow: 0 0 transparent; --tw-ring-shadow: 0 0 transparent; --tw-shadow: 0 0 transparent; --tw-shadow-colored: 0 0 transparent; --tw-blur: ; --tw-brightness: ; --tw-contrast: ; --tw-grayscale: ; --tw-hue-rotate: ; --tw-invert: ; --tw-saturate: ; --tw-sepia: ; --tw-drop-shadow: ; --tw-backdrop-blur: ; --tw-backdrop-brightness: ; --tw-backdrop-contrast: ; --tw-backdrop-grayscale: ; --tw-backdrop-hue-rotate: ; --tw-backdrop-invert: ; --tw-backdrop-opacity: ; --tw-backdrop-saturate: ; --tw-backdrop-sepia: ;">Table</span><span style="color: var(--vscode-foreground);">: Sales.Order</span>
--
-- <span style="color: var(--tw-prose-bold); border: 0px solid rgb(227, 227, 227); box-sizing: border-box; --tw-border-spacing-x: 0; --tw-border-spacing-y: 0; --tw-translate-x: 0; --tw-translate-y: 0; --tw-rotate: 0; --tw-skew-x: 0; --tw-skew-y: 0; --tw-scale-x: 1; --tw-scale-y: 1; --tw-pan-x: ; --tw-pan-y: ; --tw-pinch-zoom: ; --tw-scroll-snap-strictness: proximity; --tw-gradient-from-position: ; --tw-gradient-via-position: ; --tw-gradient-to-position: ; --tw-ordinal: ; --tw-slashed-zero: ; --tw-numeric-figure: ; --tw-numeric-spacing: ; --tw-numeric-fraction: ; --tw-ring-inset: ; --tw-ring-offset-width: 0px; --tw-ring-offset-color: #fff; --tw-ring-color: rgba(69,89,164,.5); --tw-ring-offset-shadow: 0 0 transparent; --tw-ring-shadow: 0 0 transparent; --tw-shadow: 0 0 transparent; --tw-shadow-colored: 0 0 transparent; --tw-blur: ; --tw-brightness: ; --tw-contrast: ; --tw-grayscale: ; --tw-hue-rotate: ; --tw-invert: ; --tw-saturate: ; --tw-sepia: ; --tw-drop-shadow: ; --tw-backdrop-blur: ; --tw-backdrop-brightness: ; --tw-backdrop-contrast: ; --tw-backdrop-grayscale: ; --tw-backdrop-hue-rotate: ; --tw-backdrop-invert: ; --tw-backdrop-opacity: ; --tw-backdrop-saturate: ; --tw-backdrop-sepia: ;">Columns</span><span style="color: var(--vscode-foreground);">:</span>
-- <span style="color: var(--vscode-foreground);">EmployeeId</span>
-- <span style="color: var(--vscode-foreground);">CustomerId</span>
-- <span style="color: var(--vscode-foreground);">OrderDate</span>
-- <span style="color: var(--vscode-foreground);">OrderId</span>
--
-- <span style="color: var(--tw-prose-bold); border: 0px solid rgb(227, 227, 227); box-sizing: border-box; --tw-border-spacing-x: 0; --tw-border-spacing-y: 0; --tw-translate-x: 0; --tw-translate-y: 0; --tw-rotate: 0; --tw-skew-x: 0; --tw-skew-y: 0; --tw-scale-x: 1; --tw-scale-y: 1; --tw-pan-x: ; --tw-pan-y: ; --tw-pinch-zoom: ; --tw-scroll-snap-strictness: proximity; --tw-gradient-from-position: ; --tw-gradient-via-position: ; --tw-gradient-to-position: ; --tw-ordinal: ; --tw-slashed-zero: ; --tw-numeric-figure: ; --tw-numeric-spacing: ; --tw-numeric-fraction: ; --tw-ring-inset: ; --tw-ring-offset-width: 0px; --tw-ring-offset-color: #fff; --tw-ring-color: rgba(69,89,164,.5); --tw-ring-offset-shadow: 0 0 transparent; --tw-ring-shadow: 0 0 transparent; --tw-shadow: 0 0 transparent; --tw-shadow-colored: 0 0 transparent; --tw-blur: ; --tw-brightness: ; --tw-contrast: ; --tw-grayscale: ; --tw-hue-rotate: ; --tw-invert: ; --tw-saturate: ; --tw-sepia: ; --tw-drop-shadow: ; --tw-backdrop-blur: ; --tw-backdrop-brightness: ; --tw-backdrop-contrast: ; --tw-backdrop-grayscale: ; --tw-backdrop-hue-rotate: ; --tw-backdrop-invert: ; --tw-backdrop-opacity: ; --tw-backdrop-saturate: ; --tw-backdrop-sepia: ;">Predicate</span><span style="color: var(--vscode-foreground);">: There is no explicit predicate (condition) specified in the query. It simply retrieves all rows from the "Sales.Order" table.</span>
-- <span style="color: var(--tw-prose-bold); border: 0px solid rgb(227, 227, 227); box-sizing: border-box; --tw-border-spacing-x: 0; --tw-border-spacing-y: 0; --tw-translate-x: 0; --tw-translate-y: 0; --tw-rotate: 0; --tw-skew-x: 0; --tw-skew-y: 0; --tw-scale-x: 1; --tw-scale-y: 1; --tw-pan-x: ; --tw-pan-y: ; --tw-pinch-zoom: ; --tw-scroll-snap-strictness: proximity; --tw-gradient-from-position: ; --tw-gradient-via-position: ; --tw-gradient-to-position: ; --tw-ordinal: ; --tw-slashed-zero: ; --tw-numeric-figure: ; --tw-numeric-spacing: ; --tw-numeric-fraction: ; --tw-ring-inset: ; --tw-ring-offset-width: 0px; --tw-ring-offset-color: #fff; --tw-ring-color: rgba(69,89,164,.5); --tw-ring-offset-shadow: 0 0 transparent; --tw-ring-shadow: 0 0 transparent; --tw-shadow: 0 0 transparent; --tw-shadow-colored: 0 0 transparent; --tw-blur: ; --tw-brightness: ; --tw-contrast: ; --tw-grayscale: ; --tw-hue-rotate: ; --tw-invert: ; --tw-saturate: ; --tw-sepia: ; --tw-drop-shadow: ; --tw-backdrop-blur: ; --tw-backdrop-brightness: ; --tw-backdrop-contrast: ; --tw-backdrop-grayscale: ; --tw-backdrop-hue-rotate: ; --tw-backdrop-invert: ; --tw-backdrop-opacity: ; --tw-backdrop-saturate: ; --tw-backdrop-sepia: ;">OFFSET 50 ROWS FETCH NEXT 25 ROWS ONLY</span><span style="color: var(--vscode-foreground);">: This part of the query specifies that the results should start from the 51st row and fetch the next 25 rows only, allowing for pagination of the results.</span>

-- %% [markdown]
-- ### **Q8**
--
-- ### **A Quick Look at Window Functions**

-- %%
--A Quick Look at Window Functions

-- Original Query for TSQLV4
USE TSQLV4

SELECT orderid, custid, val,
  ROW_NUMBER() OVER(PARTITION BY custid
                    ORDER BY val) AS rownum
FROM Sales.OrderValues
ORDER BY custid, val;


-- there is not sales ordervalues or ang relevent  table on Northwinds
-- Out:
-- (830 rows affected)
-- Total execution time: 00:00:00.139
-- ...

-- %% [markdown]
-- <u><mark>**the proposition, table, columns and the predicate**</mark></u>
--
-- Proposition(Problem): Retrieve the orderid, custid, val, and row number for each record in the Sales.OrderValues table, partitioned by custid and ordered by val.
--
-- Table: Sales.OrderValues
--
-- Columns:
--
-- orderid
--
-- custid
--
-- val
--
-- Predicate:
--
-- The predicate in this query is the ROW\_NUMBER() function used in the SELECT statement, which assigns a sequential integer to each row within the partition specified by the PARTITION BY clause. The rows are ordered within each partition by the ORDER BY clause, based on the val column.

-- %% [markdown]
-- ### **Q10**
--
-- ### **CASE Expression**

-- %%
--  CASE Expression

-- Original Query for TSQLV4
USE TSQLV4

-- Simple
SELECT productid, productname, categoryid,
  CASE categoryid
    WHEN 1 THEN 'Beverages'
    WHEN 2 THEN 'Condiments'
    WHEN 3 THEN 'Confections'
    WHEN 4 THEN 'Dairy Products'
    WHEN 5 THEN 'Grains/Cereals'
    WHEN 6 THEN 'Meat/Poultry'
    WHEN 7 THEN 'Produce'
    WHEN 8 THEN 'Seafood'
    ELSE 'Unknown Category'
  END AS categoryname
FROM Production.Products;



-- New Query for Northwinds
USE Northwinds2022TSQLV7;


SELECT productid, productname, categoryid,
  CASE categoryid
    WHEN 1 THEN 'Beverages'
    WHEN 2 THEN 'Condiments'
    WHEN 3 THEN 'Confections'
    WHEN 4 THEN 'Dairy Products'
    WHEN 5 THEN 'Grains/Cereals'
    WHEN 6 THEN 'Meat/Poultry'
    WHEN 7 THEN 'Produce'
    WHEN 8 THEN 'Seafood'
    ELSE 'Unknown Category'
  END AS categoryname
FROM Production.[Product];
-- Out:
-- (77 rows affected)
-- (77 rows affected)
-- Total execution time: 00:00:00.104
-- ...

-- %% [markdown]
-- <u><mark>**the proposition, table, columns and the predicate**</mark></u>
--
-- Proposition (Problem): Retrieve data from the Product table and include the category name based on the category ID.
--
-- Table: Product
--
-- Columns: productid, productname, categoryid
--
-- Predicate: CASE statement is used to conditionally return different category names based on the categoryid.

-- %%
-- Original Query for TSQLV4
USE TSQLV4

-- Searched
SELECT orderid, custid, val,
  CASE 
    WHEN val < 1000.00                   THEN 'Less than 1000'
    WHEN val BETWEEN 1000.00 AND 3000.00 THEN 'Between 1000 and 3000'
    WHEN val > 3000.00                   THEN 'More than 3000'
    ELSE 'Unknown'
  END AS valuecategory
FROM Sales.OrderValues;



-- there is not sales ordervalues or ang relevent  table on Northwinds
-- Out:
-- (830 rows affected)
-- Total execution time: 00:00:00.377
-- ...

-- %% [markdown]
-- <u><mark>**the proposition, table, columns and the predicate**</mark></u>
--
-- Proposition (Problem): The problem seems to involve categorizing orders based on their values into three categories: 'Less than 1000', 'Between 1000 and 3000', and 'More than 3000'. The query aims to select order information along with their value categories.
--
-- Table: The table referenced in the query is Sales.OrderValues.
--
-- Columns:
--
-- orderid
--
-- custid
--
-- val (presumably represents the value of the order)
--
-- Predicate:
--
-- The CASE statement is used as a conditional expression to categorize the values of orders (val) into different categories:
--
-- If the val is less than 1000, it falls into the category 'Less than 1000'.
--
-- If the val is between 1000 and 3000 (inclusive), it falls into the category 'Between 1000 and 3000'.
--
-- If the val is greater than 3000, it falls into the category 'More than 3000'.
--
-- If none of the above conditions are met, the category is marked as 'Unknown'.
